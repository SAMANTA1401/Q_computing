# %% [markdown]
# there were only two possible outcomes when we measured a qubit: 0 and 1. So we used two ket vectors to describe a qubit:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Now if I have two qubits, then when I measure the system, I could get four outcomes: 00, 01, 10 and 11. So I need to use 4 ket vectors to describe a two-qubit system:
#
# ![image.png](attachment:image.png)   [00, 01, 10, 11] for classical

# %% [markdown]
# column vector representation
#
# |0> = [1,0]
#
# |1> = [0,1]
#
# |00> = [1,0,0,0]
#
# |01> = [0,1,0,0]
#
# |10> = [0,0,1,0]
#
# |11> = [0,0,0,1]
#
# ![image.png](attachment:image.png)

# %% [markdown]
# a two-qubit system as:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 3 qubits:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# n qubits

# %% [markdown]
# a|00000000...nth> + b|00000000......1> + .......2^n th

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# it written as:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# These all mean the same thing but just are different ways of writing it down

# %% [markdown]
# ![image.png](attachment:image.png)  becomes
#
# ![image-2.png](attachment:image-2.png) ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Swap Gates
#
# ![image-3.png](attachment:image-3.png) ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# sends it to:
#
# ![image.png](attachment:image.png)
#
# can rewrite as:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Controlled Gates

# %% [markdown]
# where a gate only has an effect if another qubit is in a particular state. We can do this with the concept of controlled gates.

# %% [markdown]
# the CNOT gate. The CNOT gate or controlled not gate takes in two qubits: a control qubit and a target qubit. If the control qubit is 1 then it applies a NOT gate to the target qubit.
#
# ![image.png](attachment:image.png)
#
# where C represents the control qubit and T represents the target qubit.

# %% [markdown]
# the control qubit is 0 the CNOT gate does not change this state

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# the control qubit is 1 it will change the target qubit to 1 so we get
#
# ![image.png](attachment:image.png)

# %% [markdown]
# for a general two-qubit system
#
# ![image.png](attachment:image.png)

# %% [markdown]
# CNOT gate will flip the target qubit where the control qubit is 1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Single Qubit Gates on Multi Qubit Systems

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# apply the Hadamard gate just to the A qubit

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# = ![image.png](attachment:image.png)

# %% [markdown]
# this means is that we want to apply a Hadamard Gate to the first qubit and the identity gate e.g. the fate that does nothing to the second qubit.

# %% [markdown]
# ![image.png](attachment:image.png) = ![image-2.png](attachment:image-2.png)

# %% [markdown]
# this is called the tensor product of two matrices

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
