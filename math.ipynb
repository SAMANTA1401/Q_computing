# %% [markdown]
# https://medium.com/@charlie.thomas_94667/basic-mathematics-for-quantum-mechanics-linear-maps-605e0a71632c

# %% [markdown]
# set

# %% [markdown]
# A set is a collection of objects. We denote a set by putting the list of objects in curly brackets. Here are some examples: {1,2,3} ,{a,b,c,d,e,f,g,h}
#
# that sets do not have duplicate items.

# %% [markdown]
# The natural numbers are the set of positive whole numbers 0 to infinity (N)

# %% [markdown]
# The integers are the set of whole numbers -inf to +inf(Z)

# %% [markdown]
# map

# %% [markdown]
# A map is a way of relating items in one set to items in another set. If we have a map called f from set A to set B we write:
#
# f : A -> B

# %% [markdown]
# ![image.png](attachment:image.png)![image-2.png](attachment:image-2.png)![image-3.png](attachment:image-3.png)

# %% [markdown]
# Domains, Codomain and Range
# The domain of a map is the set the map goes from and the codomain is the set it goes to.Then A is the domain and B is the codomain

# %% [markdown]
# The range of a function is the set of all the outputs of a function. This sounds very similar to the codomain but it is slightly different. To see this let’s look at an example. If we have the following map:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Then the domain and the codomain are the set of integers. However, any integer squared is always positive so the range of the function is just the positive integers. So -1 is in the codomain but not in the range.

# %% [markdown]
# Injective maps
# Some maps are called ‘injective’ or ‘one-to-one’. An injective map is one where no two inputs have the same output. Consider:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# not injective because 2 and 3 both go the same output.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# When a map is injective, every output (e.g. everything in the range) has a unique inverse — we can tell exactly what the input was just from looking at the output

# %% [markdown]
# Surjective maps
#
# Surjective maps are also called ‘onto’ maps. A surjective map is one where the co-domain is the same as the range — this means the function produces every possible output.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# is not surjective as it will never produce -1.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# is surjective as it will produce all the possible outputs e.g. all of the integers.

# %% [markdown]
# Bijective maps
#
# Some maps are both injective and surjective so we call these maps bijective. Sometimes you’ll hear these maps called a bijection.

# %% [markdown]
# Binary operations
#
# Some maps can take more than one input. For example, addition is an example of a map that takes two inputs and gives us back a single output.
#
# A map f from two sets A and B to a third C is written like this:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# A map can take any number of inputs but if it takes two inputs we call it a binary operation

# %% [markdown]
# Complex Number

# %% [markdown]
# ![image.png](attachment:image.png)![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Conjugation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# componendo and dividendo

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# r and t have special names. r is called the modulus of the complex number and t is called the argument.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Euler’s Formula

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Vector Space

# %% [markdown]
# A vector space is a collection of two sets and two binary operations.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# inner product or dot product
#
# V-> vector and S-> scaler

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Conjugate

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Linearity

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# inner product of a vector with itself

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# size of a vector v as |v|

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Angle

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Dot products for complex numbers

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# linear combination

# %% [markdown]
# vectors v and w ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# span of a linear combination

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The set of all vectors we can make from them is called the span.

# %% [markdown]
# span of these vectors

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# linear independence
#
# Given a set of a vectors P and a vector c, we can ask if c is in the span of P
#
# If c is not in the span of P then we say c is linearly independent of P because we cannot write it as a linear combination of the vectors in P.

# %% [markdown]
# If c is in the span of P then we day it is linearly dependent

# %% [markdown]
# Linearly independent set

# %% [markdown]
# Given a set of vectors we can ask if I take a vector out of the set is it linearly independent to all the other vectors.
#
# If every vector in a set is linearly independent from every other vector in the set then we say that the set is linearly dependent

# %% [markdown]
# basis

# %% [markdown]
#  if there is a set of vectors such that they span the whole space.

# %% [markdown]
# all the vectors in the vector space out of some smaller subset of the vectors.that the set is linearly independent.

# %% [markdown]
# If there is a linearly independent set of vectors that spans the whole space we call that set a basis

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This is a basis as we can write any vector as a linear combination of them

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# And they are linearly independent from each other as we can’t write one in terms of the other

# %% [markdown]
# column vectors

# %% [markdown]
# basis ![image.png](attachment:image.png)

# %% [markdown]
# any vector using them   ![image.png](attachment:image.png)

# %% [markdown]
# where the a’s are scalars

# %% [markdown]
# We can write all the a’s as a column which is our column vector so

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# So all a column vector is, is a representation of a vector using a particular basis

# %% [markdown]
# matrices

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2X3 * 3X2 = 2X2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Identity matrix

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# I = ![image.png](attachment:image.png)

# %% [markdown]
# Inverse matrices

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# linear map

# %% [markdown]
# Let f be a map between two vector spaces
#
# If

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# where v, w are vectors and a and b are scalars then f is a linear map

# %% [markdown]
# Linear maps are completely determined by its action on the basis

# %% [markdown]
# Let f be a linear map
#
# Let V have the following basis

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  v = ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# what f does to each basis vector, then we know what it does to any vector.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Linear maps that return vectors

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)![image-2.png](attachment:image-2.png)

# %% [markdown]
# every matrix is actually just describing a linear map.

# %% [markdown]
# a matrix A then we write Av to represent passing the vector v to matrix A

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)![image-2.png](attachment:image-2.png)

# %% [markdown]
# Matrices as linear maps
#
# We’ve just seen that linear maps correspond to matrices. Where the ith column tells us what happens to the ith basis vector under the map.
#
# While this is true, there is one caveat. Vector spaces can have more than one basis. So when we write a linear map as a matrix we have chosen a specific basis to use. If we change the basis then the linear map will be represented by a different basis.

# %% [markdown]
# a matrix A and two vectors v and w. If I want to work out Av and Aw

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# v' = f(v) = Av
#
# w' = f(w) = Aw

# %% [markdown]
# A[v,w] = [Av, Aw]

# %% [markdown]
# Matrix multiplication as the composition of linear maps

# %% [markdown]
# a linear map f from X to Y and another linear map g from Y to Z then

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Let’s assume f goes from an m-dimensional space to an n-dimensional space. So its matrix will need m columns — one for each dimension of the input space and n rows — one for each dimension of the output space.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  g takes in the output from f it must go from an n-dimensional space but then it can go to any dimensional space so let’s just say it is a p-dimensional space. So g will have n columns and p rows.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Eigenvectors

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# A matrix

# %% [markdown]
# w and v vectors

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# s scaler

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# v is an eigenvector of A with eigenvalue -3

# %% [markdown]
# Hermitian Matrices

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)= ![image.png](attachment:image.png)

# %% [markdown]
# If a matrix is its own transpose we may say that the matrix is symmetric

# %% [markdown]
# Conjugate transpose of a matrix

# %% [markdown]
# replace every element by its complex conjugate and then we take the transpose.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# conjugate transpose

# %% [markdown]
# ![image.png](attachment:image.png) = ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Hermitian matrices

# %% [markdown]
# A Hermitian matrix is simply one that is equal to its own conjugate transpose

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Hermitian matrix as it is equal to its conjugate transpose

# %% [markdown]
# Unitary matrices

# %% [markdown]
#  A matrix, A, is unitary if its inverse is its conjugate transpose.

# %% [markdown]
# AA^-1 = I

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# A^-1 = A^+

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
