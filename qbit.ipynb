# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# classical bit 0 and 1
#
# not gate

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# q bit |0> and |1>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# it evolves in time according to some unitary matrix U.
#
# In Quantum Computing, there is the idea of a quantum gate, which acts on a qubit. Just like a regular logic gate acts on a classical bit. Now a quantum gate changes a quantum state so it must be represented by a unitary matrix.

# %% [markdown]
# single qubit.

# %% [markdown]
# we can represent a qubit as a column vector:

# %%
# |0> = [1       a|0> = [a
#        0]              0]

# |1> = [0       b|1> = [0
#        1]              b]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# the NOT gate by the matrix:

# %% [markdown]
# ![image.png](attachment:image.png)  ![image-3.png](attachment:image-3.png) ![image-4.png](attachment:image-4.png)This gate is also known as the Pauli  X gate because it is part of a family of three gates with the others called the Y and Z gates.

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png) ![image-3.png](attachment:image-3.png) ![image-4.png](attachment:image-4.png)

# %% [markdown]
# Pauli Gates

# %% [markdown]
# ![image-2.png](attachment:image-2.png) ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)![image-3.png](attachment:image-3.png)![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Hadamard Matrix

# %% [markdown]
# it allows us to put qubits into a state where they are equally likely to be 0 or 1.

# %% [markdown]
# ![image.png](attachment:image.png)  ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
