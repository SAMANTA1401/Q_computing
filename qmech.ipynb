# %% [markdown]
# flip a coin in classical mechanics

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 0.5|H> + 0.5|T>
#
# 0.5 + 0.5=1 total probability
#
# 0.5 probability for occurrence of head and tail only two discrete states and occur only one at a time

# %% [markdown]
# Quantum Mechanics, the states form a complex vector space

# %% [markdown]
# all multiples of that state are also possible. If it also means if I have two or more states then all linear combinations of those states are possible.

# %% [markdown]
# So in the case of our quantum coin, we don’t have just have the two states above we have all the linear combinations of them. So all the states of the form

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# where a, b are complex numbers are possible. and a bar , b bar are complex conjugates

# %% [markdown]
# when we do a measurement the state collapses.
#
# Now, we can ask if we can know what the state will collapse into? Well, we can’t know exactly but we can know the probability.

# %% [markdown]
# Then the probability of measuring heads is given by

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# the probability of measuring tails is given by:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# his imposes an important restriction on what states are possible. Since we know probabilities add up to 1 we must have:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# for all valid quantum states

# %% [markdown]
# ![image.png](attachment:image.png) is a valid quantum state because

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Phases

# %% [markdown]
# ![image.png](attachment:image.png) = cost + isint = x+iy

# %% [markdown]
# x = cost
#
# y = sint

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This means for any quantum state, I can multiply any of the coefficients by a number of this form without changing the probabilities of what I’ll measure.
#
# whatever value t has

# %% [markdown]
# like a sin or cos curve for different phase we always get the value between -1 and 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)   is a phase

# %% [markdown]
#  the phase difference between the coefficients actually can be detected. This means:

# %% [markdown]
# ![image.png](attachment:image.png)  is different to

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# if the phase applies to the whole state:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# then we cannot determine this difference so it is the same as:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If a phase applies to the whole we call it a global phase.

# %% [markdown]
# Evolving states

# %% [markdown]
# how quantum states change in time. In general, a quantum state changes in time according to some unitary matrix U.

# %% [markdown]
# The reason the matrix must be unitary is that unitary matrices conserve probabilities

# %% [markdown]
# ![image.png](attachment:image.png) complex conjugates transposed matrices

# %% [markdown]
# if a = x +iy ; a bar = x -iy
#
# a.a bar = (x+iy)(x-iy) = x^2+y^2

# %% [markdown]
# this will be 1 if x = cost and y = sint

# %% [markdown]
# if x = Zcost and y = Zsint then not equal to 1 and equal to Z

# %% [markdown]
# total probablity = ![image.png](attachment:image.png)  (complex conjugates )

# %% [markdown]
# Then multiplying  vector v by a unitary matrix A does not change this fact

# %% [markdown]
# A|v> ket vectors

# %% [markdown]
# Well for a closed system — that is a system where nothing interferes with it it evolves according to the Hamiltonian — which you can think of as describing the energy of the system.
#
# However, in Quantum Computing, we actually deal with open systems because we force the state to evolve in certain ways, so we can the unitary matrix that we want to use.

# %% [markdown]
# Qubits

# %% [markdown]
# bit  in classical computer systems 0 and 1

# %% [markdown]
# qubit is just another quantum system

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# a and b are probabilities (scaler matrix may be complex) and 0 and 1 like unit vectors

# %% [markdown]
# Braket notation

# %% [markdown]
# ![image-2.png](attachment:image-2.png)  ![image.png](attachment:image.png)

# %% [markdown]
# ket vectors

# %% [markdown]
# ![image.png](attachment:image.png) bra vectors

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This combination of a bra and ket (a bracket) stands for taking the inner product between the two vectors.

# %% [markdown]
# dot product (H ,H)

# %% [markdown]
# Orthogonality

# %% [markdown]
# quantum states.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# They are orthonormal. What this means is that:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# look like dot product of unit vectors 0^ and 1^
