# %%
from qiskit import *

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
circuit = QuantumCircuit(2) # two qubit  |0> and |1>
circuit.h(0)
circuit.cx(0, 1) # cnot()
circuit.draw(output='mpl')

# %%
from qiskit_aer import Aer

# %%
from qiskit import transpile
simulator = Aer.get_backend('statevector_simulator')
trans_result = transpile(circuit, simulator)
result = simulator.run(trans_result).result()
print(result)
# Out:
# Result(backend_name='statevector_simulator', backend_version='0.13.3', qobj_id='', job_id='640449fb-bc52-4477-8442-172236213504', success=True, results=[ExperimentResult(shots=1, success=True, meas_level=2, data=ExperimentResultData(statevector=Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,
#              0.70710678+0.j],
# ...

# %%
statevector = result.get_statevector()

# %%
statevector
# Out:
# Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,
#              0.70710678+0.j],
#             dims=(2, 2))

# %%
from qiskit.visualization import plot_histogram, array_to_latex, plot_bloch_multivector

# %%
array_to_latex(statevector)
# Out:
# $$
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & 0 & 0 & \frac{\sqrt{2}}{2}  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
simulator = Aer.get_backend('statevector_simulator')

# %%
trans_result = transpile(circuit, simulator)
result = simulator.run(trans_result).result()
print(result)
# Out:
# Result(backend_name='statevector_simulator', backend_version='0.13.3', qobj_id='', job_id='72714ee8-788f-4503-8928-102b43001458', success=True, results=[ExperimentResult(shots=1, success=True, meas_level=2, data=ExperimentResultData(statevector=Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,
#              0.70710678+0.j],
# ...

# %%
statevector = result.get_statevector()

# %%
statevector
# Out:
# Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,
#              0.70710678+0.j],
#             dims=(2, 2))

# %%
array_to_latex(statevector)
# Out:
# $$
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & 0 & 0 & \frac{\sqrt{2}}{2}  \\
#  \end{bmatrix}
# $$

# %%
circuit.measure_all()

# %%
simulator = Aer.get_backend('qasm_simulator')

# %%
trans_result = transpile(circuit, simulator)
result = simulator.run(trans_result).result()
print(result)
# Out:
# Result(backend_name='qasm_simulator', backend_version='0.13.3', qobj_id='', job_id='c6a1419d-9b00-42f8-b9d3-76d44b408883', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'0x3': 520, '0x0': 504}), header=QobjExperimentHeader(creg_sizes=[['meas', 2]], global_phase=0.0, memory_slots=2, n_qubits=2, name='circuit-165', qreg_sizes=[['q', 2]], metadata={}), status=DONE, seed_simulator=1425647187, metadata={'batched_shots_optimization': False, 'required_memory_mb': 0, 'method': 'stabilizer', 'active_input_qubits': [0, 1], 'device': 'CPU', 'remapped_qubits': False, 'num_qubits': 2, 'num_clbits': 2, 'time_taken': 0.0608497, 'sample_measure_time': 0.0092574, 'input_qubit_map': [[0, 0], [1, 1]], 'max_memory_mb': 8072, 'measure_sampling': True, 'noise': 'ideal', 'parallel_shots': 1, 'parallel_state_update': 8, 'runtime_parameter_bind': False, 'num_bind_params': 1, 'fusion': {'enabled': False}}, time_taken=0.0608497)], date=2025-03
# ...

# %%
counts = result.get_counts()

# %%
counts
# Out:
# {'11': 520, '00': 504}

# %%
plot_histogram(result.get_counts())

# %%
trans_result = transpile(circuit, simulator)
result = simulator.run(trans_result).result()
print(result)
# Out:
# Result(backend_name='qasm_simulator', backend_version='0.13.3', qobj_id='', job_id='e99cfb69-c765-424a-ab94-10ec4da618a4', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'0x0': 485, '0x3': 539}), header=QobjExperimentHeader(creg_sizes=[['meas', 2]], global_phase=0.0, memory_slots=2, n_qubits=2, name='circuit-165', qreg_sizes=[['q', 2]], metadata={}), status=DONE, seed_simulator=1728074283, metadata={'batched_shots_optimization': False, 'required_memory_mb': 0, 'method': 'stabilizer', 'active_input_qubits': [0, 1], 'device': 'CPU', 'remapped_qubits': False, 'num_qubits': 2, 'num_clbits': 2, 'time_taken': 0.0035881, 'sample_measure_time': 0.0013869, 'input_qubit_map': [[0, 0], [1, 1]], 'max_memory_mb': 8072, 'measure_sampling': True, 'noise': 'ideal', 'parallel_shots': 1, 'parallel_state_update': 8, 'runtime_parameter_bind': False, 'num_bind_params': 1, 'fusion': {'enabled': False}}, time_taken=0.0035881)], date=2025-03
# ...

# %%
counts = result.get_counts()

# %%
counts
# Out:
# {'00': 485, '11': 539}

# %%
plot_histogram(result.get_counts())

# %%
trans_result = transpile(circuit, simulator)
result = simulator.run(trans_result).result()
print(result)
# Out:
# Result(backend_name='qasm_simulator', backend_version='0.13.3', qobj_id='', job_id='c14382c0-494f-4ed0-9299-24282e38b3e1', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'0x0': 509, '0x3': 515}), header=QobjExperimentHeader(creg_sizes=[['meas', 2]], global_phase=0.0, memory_slots=2, n_qubits=2, name='circuit-165', qreg_sizes=[['q', 2]], metadata={}), status=DONE, seed_simulator=3243364725, metadata={'batched_shots_optimization': False, 'required_memory_mb': 0, 'method': 'stabilizer', 'active_input_qubits': [0, 1], 'device': 'CPU', 'remapped_qubits': False, 'num_qubits': 2, 'num_clbits': 2, 'time_taken': 0.0043133, 'sample_measure_time': 0.0017847, 'input_qubit_map': [[0, 0], [1, 1]], 'max_memory_mb': 8072, 'measure_sampling': True, 'noise': 'ideal', 'parallel_shots': 1, 'parallel_state_update': 8, 'runtime_parameter_bind': False, 'num_bind_params': 1, 'fusion': {'enabled': False}}, time_taken=0.0043133)], date=2025-03
# ...

# %%
counts = result.get_counts()

# %%
counts
# Out:
# {'00': 509, '11': 515}

# %%
plot_histogram(result.get_counts())

# %%
circuit = QuantumCircuit(2)
circuit.x(1) # not gate
circuit.h(0) # hadamard gate
circuit.cx(0, 1) # cnot gate
circuit.draw(output='mpl')

# %%
simulator = Aer.get_backend('statevector_simulator')

# %%
trans_result = transpile(circuit, simulator)
result = simulator.run(trans_result).result()
print(result)
# Out:
# Result(backend_name='statevector_simulator', backend_version='0.13.3', qobj_id='', job_id='93c0f92c-25dd-4c42-b593-e3a8c22de691', success=True, results=[ExperimentResult(shots=1, success=True, meas_level=2, data=ExperimentResultData(statevector=Statevector([0.        +0.j, 0.70710678+0.j, 0.70710678+0.j,
#              0.        +0.j],
# ...

# %%
statevector = result.get_statevector()

# %%
statevector
# Out:
# Statevector([0.        +0.j, 0.70710678+0.j, 0.70710678+0.j,
#              0.        +0.j],
#             dims=(2, 2))

# %%
array_to_latex(statevector)
# Out:
# $$
#
# \begin{bmatrix}
# 0 & \frac{\sqrt{2}}{2} & \frac{\sqrt{2}}{2} & 0  \\
#  \end{bmatrix}
# $$

# %%
circuit.measure_all()
simulator = Aer.get_backend('qasm_simulator')

# %%
trans_result = transpile(circuit, simulator)
result = simulator.run(trans_result).result()
print(result)
# Out:
# Result(backend_name='qasm_simulator', backend_version='0.13.3', qobj_id='', job_id='6f33b3ad-1c2e-4871-a8a1-2afffff91a4e', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'0x1': 526, '0x2': 498}), header=QobjExperimentHeader(creg_sizes=[['meas', 2]], global_phase=0.0, memory_slots=2, n_qubits=2, name='circuit-173', qreg_sizes=[['q', 2]], metadata={}), status=DONE, seed_simulator=2972791995, metadata={'batched_shots_optimization': False, 'required_memory_mb': 0, 'method': 'stabilizer', 'active_input_qubits': [0, 1], 'device': 'CPU', 'remapped_qubits': False, 'num_qubits': 2, 'num_clbits': 2, 'time_taken': 0.0034781, 'sample_measure_time': 0.001396, 'input_qubit_map': [[0, 0], [1, 1]], 'max_memory_mb': 8072, 'measure_sampling': True, 'noise': 'ideal', 'parallel_shots': 1, 'parallel_state_update': 8, 'runtime_parameter_bind': False, 'num_bind_params': 1, 'fusion': {'enabled': False}}, time_taken=0.0034781)], date=2025-03-
# ...

# %%
counts = result.get_counts()
plot_histogram(result.get_counts())
