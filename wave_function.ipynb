# %% [markdown]
# What is a Wave Function?
# The wave function, denoted
# 𝜓
# ψ (psi), is a mathematical function that describes the quantum state of a system (e.g., a qubit, a pair of entangled qubits, or even a larger system). It encodes all possible information about the system’s behavior before measurement, including probabilities of different outcomes.
#
# Definition: For a single particle or qubit,
# 𝜓
# ψ is a complex-valued function of position, time, or other variables (e.g.,
# 𝜓
# (
# 𝑥
# ,
# 𝑡
# )
# ψ(x,t) for a particle in space, or a vector for a qubit).
# Quantum State: In quantum computing, we often represent
# 𝜓
# ψ as a vector in a Hilbert space
# (e.g.,
# ∣ψ⟩=α∣0⟩+β∣1⟩ for a qubit).

# %% [markdown]
# A Hilbert Space is a complete, inner-product space. In simpler terms:
# Vector space: It's a space where vectors can be added and scaled.
# Inner product: It has an inner product (or dot product) that measures the similarity between vectors.
# Complete: It's complete, meaning that any Cauchy sequence of vectors converges to a vector in the space.

# %% [markdown]
# The wave function isn’t directly observable—it’s a tool to predict what happens when we measure the system.
# It evolves smoothly over time (via the Schrödinger equation) until a measurement collapses it to a definite state.

# %% [markdown]
# ![image.png](attachment:image.png)![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
